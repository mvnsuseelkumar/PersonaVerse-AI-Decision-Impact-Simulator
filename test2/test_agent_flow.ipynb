# %% [markdown]
# # Data

# %%
from typing import TypedDict,Annotated
from pydantic import BaseModel,Field
import operator

# %%
class DiscussionMessage(BaseModel):

    round: int

    persona_id: str

    persona_name: str

    content: str


class ChatMessage(BaseModel):
    role: str
    content: str


class PersonaDefinition(BaseModel):
    id: str
    name: str
    age: int
    gender:str
    behavior: str
    expertise: str
    goal: str
    personality: str
    speaking_style: str

class PersonasResponse(BaseModel):
    personas: list[PersonaDefinition]

class RuntimePersona(PersonaDefinition):
    model: str | None = None
    chat_history: list[ChatMessage] = Field(default_factory=list)

# %%
from copy import deepcopy

def merge_personas(old: dict[str, RuntimePersona],new: dict[str, RuntimePersona]) -> dict[str, RuntimePersona]:

    merged = deepcopy(old)

    for persona_id, update in new.items():

        if persona_id not in merged:
            merged[persona_id] = update
            continue
        persona = merged[persona_id]

        # This is For When A model Is Provided in The Worker Node It Will Updated Here
        if update.model is not None:
            persona.model = update.model

        # It will Add or Append The new Messages if Existed
        if update.chat_history:
            persona.chat_history.extend(update.chat_history)

    return merged

# %%
class State(TypedDict):

    query: str

    num_personas: int
    
    personas: Annotated[
        dict[str, RuntimePersona],
        merge_personas
    ]

    discussion: Annotated[
        list[DiscussionMessage],
        operator.add
    ]

    review_summary: str

    critic_feedback: str

    final_answer: str

    final_discussion_summary: str

    round: int

    max_rounds: int

    judge_approved: bool

    judge_reason: str

    # available_models:list[str]

# %%
class JudgeDecision(BaseModel):
    judge_approved: bool
    judge_reason: str

# %% [markdown]
# # Graph

# %% [markdown]
# ## Persona Planner/Creator

# %%
from langchain.chat_models import init_chat_model
from langchain_core.prompts import ChatPromptTemplate

# %%
llm_planner=init_chat_model(
    model="qwen2.5:3b",
    model_provider="ollama"
)
llm_planner_struct= llm_planner.with_structured_output(PersonasResponse)
planner_prompt = ChatPromptTemplate.from_messages(
    [
        (
            "system",
            """
                You are an expert AI Debate Planner.

                Your task is to design a team of expert personas that will collaboratively analyze and debate the user's problem from multiple perspectives.

                Instructions:

                1. Generate EXACTLY {num_personas} personas.
                2. Select personas that are directly relevant to solving the user's problem.
                3. Every persona must contribute a unique perspective and expertise.
                4. Avoid duplicate or highly similar roles.
                5. The combined panel should provide comprehensive coverage of the problem.
                6. Each generated persona must populate every field required by the output schema with meaningful and contextually relevant values.
                7. Prefer realistic and professional expert roles whenever appropriate.
                8. If multiple experts belong to the same domain, ensure they have clearly different objectives, reasoning styles, or viewpoints.
                9. The personas should be capable of constructive disagreement when appropriate instead of reaching identical conclusions.
                10. Ensure diversity in:
                - Expertise
                - Decision-making style
                - Priorities
                - Risk tolerance
                - Perspective
                11. Prioritize relevance over diversity. Every persona must have a meaningful contribution toward solving the user's problem.
                12. Each persona should be able to independently analyze the problem, defend its viewpoint with logical reasoning, respectfully challenge other viewpoints when appropriate, and adapt its opinion if presented with stronger evidence during later discussion rounds.
                13. Return ONLY the structured output matching the provided schema.
                14. Do NOT include explanations, markdown, code fences, or any additional text outside the structured output.
            """
        ),
        (
            "human",
            """
                User Query:
                {query}

                Required Number of Personas:
                {num_personas}

                Design the highest-quality expert panel possible for this problem.
            """
        ),
    ]
)
def persona_planner(state:State):
    messages = planner_prompt.format_messages(
        query=state["query"],
        num_personas=state["num_personas"],
    )

    try:
        response=llm_planner_struct.invoke(messages)
    except Exception as e:
        raise RuntimeError(f"Personas Generation Failed: {e}")
    runtime_personas={}
    for i, persona in enumerate(response.personas, start=1):
        runtime_personas[f"persona{i}"] = RuntimePersona(
        id=f"persona{i}",
        **persona.model_dump(exclude={"id"})
    )
    return {
        "personas": runtime_personas
    }

# %% [markdown]
# ## Dispatch/Run Parallel Agents

# %%
from langgraph.types import Send

# %%
def dispatcher(state:State):
    personas=state["personas"]
    sends=[]
    for persona in personas.values():
        sends.append(
            Send(
                "worker",
                {
                    **state,
                    "current_persona":persona
                }
            )
        )
    
    return sends

# %% [markdown]
# ## Agent/Worker Node

# %%
from langchain_core.prompts import ChatPromptTemplate
import random
from langchain.chat_models import init_chat_model
import json

# %% [markdown]
# ### Models

# %%
MODELS={
    "qwen2.5:3b":init_chat_model(
        model="qwen2.5:3b",
        model_provider="ollama"
    ),

    "phi4-mini":init_chat_model(
    model="phi4-mini",
    model_provider="ollama"
    )
}
AVAILABLE_MODELS = list(MODELS.keys())

# %%
worker_prompt = ChatPromptTemplate.from_messages(
    [
        (
            "system",
            """
                You are participating in a multi-agent discussion.

                You must always respond according to your assigned persona.

                Persona Information

                Name: {name}

                Age: {age}

                Gender:{gender}

                Expertise: {expertise}

                Behavior: {behavior}

                Personality: {personality}

                Speaking Style: {speaking_style}

                Goal: {goal}

                Current Round:
                {round}

                Review Summary:
                {review_summary}

                Critic Feedback:
                {critic_feedback}

                Discussion So Far (JSON):
                {discussion}

                Your Previous Messages (JSON):
                {chat_history}

                Interpret these JSON arrays as the discussion history and your previous responses.

                Each object represents one message.

                Use these histories to understand previous reasoning before generating your next response.
                
                The discussion is ordered chronologically from oldest to newest.
                
                The latest messages represent the most recent state of the discussion.

                Instructions:

                - Keep your response concise (around 100–400 words) unless more detail is necessary.
                - Stay consistent with your assigned persona throughout the discussion.
                - Use your expertise and professional perspective to guide your reasoning and support your response.
                - Build upon the existing discussion instead of starting from scratch.
                - Contribute new insights whenever possible.
                - Do not repeat your previous arguments verbatim unless reinforcement is necessary.
                - If another persona presents a stronger argument, you may revise your opinion and clearly explain why.
                - Do not agree simply for the sake of agreement. Respectfully challenge viewpoints when you disagree, supporting your reasoning with evidence or logical arguments.
                - Consider the reviewer summary and critic feedback when refining your response.
                - Focus on helping the group reach the most accurate and well-reasoned conclusion.
                - Respond naturally as your assigned persona.
                - Give one thoughtful response.
            """
        ),
        (
            "human",
            """
                User Query:

                {query}
            """
        )
    ]
)

def worker(state:State):
    persona=state["current_persona"]
    model=random.choice(AVAILABLE_MODELS)
    llm=MODELS[model]
    messages=worker_prompt.format_messages(

        query=state["query"],

        name=persona.name,

        age=persona.age,

        gender=persona.gender,

        expertise=persona.expertise,

        behavior=persona.behavior,

        personality=persona.personality,

        speaking_style=persona.speaking_style,

        goal=persona.goal,

        round=state["round"],

        review_summary=state["review_summary"],

        critic_feedback=state["critic_feedback"],

        discussion=json.dumps([msg.model_dump() for msg in state["discussion"]],indent=2,ensure_ascii=False),

        chat_history=json.dumps([msg.model_dump() for msg in persona.chat_history],indent=2,ensure_ascii=False)
        
    )

    try:
        response = llm.invoke(messages)
    except Exception as e:
        raise RuntimeError(
            f"Worker '{persona.name}' failed using model '{model}': {e}"
        )

    new_chat_insertion=ChatMessage(
        role=persona.name,
        content=response.content
    )

    updated_persona=RuntimePersona(
        **persona.model_dump(exclude={"model","chat_history"}),
        model=model,
        chat_history=[new_chat_insertion]
    )

    discussion_msg=DiscussionMessage(
        round=state["round"],
        persona_id=persona.id,
        persona_name=persona.name,
        content=response.content
    )

    return {
        "personas": {
            persona.id:updated_persona
        },
        "discussion": [
            discussion_msg
        ]
    }

# %% [markdown]
# ## Reviewer

# %%
reviewer_prompt = ChatPromptTemplate.from_messages([
        (
            "system",
            """
                You are an impartial discussion reviewer.

                Your role is to objectively summarize the discussion.

                You must never introduce new opinions, assumptions, recommendations, or solutions.

                Your responsibilities:

                - Summarize the key arguments presented by each persona.
                - Identify major agreements.
                - Identify major disagreements.
                - Highlight important evidence or reasoning.
                - Mention unresolved questions or uncertainties.
                - Keep the summary concise and factual, and well organized.
                - Do not favor any persona.
                - Do not critique the discussion.
                - Do not provide a final decision.
                - Preserve the intent of each persona's arguments without changing their meaning.
                - Return only the review summary as plain text.
                - Do not use markdown, bullet points, JSON, XML, or code blocks.
                - Do not omit important arguments even if they are mentioned by only one persona.
            """
        ),

        (
            "human",
            """
                User Query:

                {query}

                Current Round:

                {round}

                Discussion (JSON):

                {discussion}
                
                Each JSON object represents one discussion message.

                The discussion is ordered chronologically from oldest to newest.

                Base your summary only on the discussion provided.

                Do not invent arguments or facts that are not present.
            """
        )

])
llm_reviewer=init_chat_model(
    model="phi4-mini",
    model_provider="ollama"
)
def reviewer(state:State):
    messages=reviewer_prompt.format_messages(
        query=state["query"],

        round=state["round"],

        discussion=json.dumps([msg.model_dump() for msg in state["discussion"]],indent=2,ensure_ascii=False)
    )

    try:

        response = llm_reviewer.invoke(messages)

    except Exception as e:

        raise RuntimeError(

            f"Reviewer failed: {e}"

        )
    
    return {

        "review_summary": response.content

    }

# %% [markdown]
# ## Critic

# %%
from langchain_core.prompts import ChatPromptTemplate
from langchain.chat_models import init_chat_model

# %%
critic_prompt = ChatPromptTemplate.from_messages([
    (
        "system",
        """
            You are an expert discussion critic.

            Your responsibility is to improve the quality of the discussion.

            You must NEVER answer the user's question yourself.

            You must NEVER summarize the discussion.

            Instead, critically evaluate the discussion and identify how it can be improved.

            Responsibilities:

            - Identify weak or unsupported arguments.
            - Identify logical inconsistencies.
            - Identify missing perspectives or expertise.
            - Identify assumptions that require evidence.
            - Point out unanswered questions.
            - Detect if important risks or opportunities were ignored.
            - Detect repetitive or redundant arguments that do not meaningfully advance the discussion.
            - Suggest specific topics, assumptions, or questions that should be addressed in the next discussion round.
            - Be objective and constructive.
            - Do not criticize writing style.
            - Focus only on the quality, completeness, and logical consistency of the reasoning.
            - Your feedback will be provided to all discussion participants in the next round.
            - Write feedback that is specific, actionable, and focused on improving the quality of reasoning.
            - Do not introduce new solutions or arguments.
            - Only evaluate the quality of the existing discussion.
            - Use the reviewer summary as a high-level overview of the discussion and rely on the discussion history to verify details.
            - Prioritize feedback that will most improve the next discussion round.
            - Distinguish between disagreements caused by missing evidence and disagreements caused by different priorities or values.
            
            Return only constructive feedback as plain text that can be directly used by the discussion participants in the next round.

            Do not use markdown, bullet points, JSON, XML, or code blocks.
        """
    ),

    (
        "human",
        """
            User Query:

            {query}

            Current Round:

            {round}

            Reviewer Summary:

            {review_summary}

            Discussion (JSON):

            {discussion}

            Each JSON object represents one discussion message.

            The discussion is ordered chronologically.

            Evaluate the discussion and provide constructive feedback for improving the next discussion round.
        """
    )

])
llm_critic=init_chat_model(
    model="qwen2.5:3b",
    model_provider="ollama"
)
def critic(state:State):
    messages=critic_prompt.format_messages(

        query=state["query"],

        round=state["round"],

        review_summary=state["review_summary"],

        discussion=json.dumps([msg.model_dump() for msg in state["discussion"]],indent=2,ensure_ascii=False)

    )

    try:
        response=llm_critic.invoke(messages)
    except Exception as e:
        raise RuntimeError(f"Critic Failed : {e}")
    
    return {

        "critic_feedback": response.content

    }

# %% [markdown]
# ## Judge

# %%
from langchain.chat_models import init_chat_model

# %%
llm_judge=init_chat_model(
    model="qwen2.5:3b",
    model_provider="ollama"
)
llm_judge_struct=llm_judge.with_structured_output(JudgeDecision)
judge_prompt = ChatPromptTemplate.from_messages([
    (
        "system",
        """
            You are the judge of a multi-agent discussion.

            You must NEVER answer the user's question.

            You must NEVER summarize the discussion.

            Your only responsibility is to determine whether another discussion round is likely to meaningfully improve the quality of the final answer.

            Consider:

            - Has the discussion reached a well-reasoned conclusion?
            - Are important questions still unanswered?
            - Are there significant disagreements that require another round?
            - Does the critic identify meaningful improvements?
            - Is another discussion round likely to meaningfully improve the quality or correctness of the final answer?
            - Use the reviewer summary as a high-level overview, the critic feedback to identify remaining weaknesses, and the discussion history to verify important details.

            Rules:

            - If the discussion is already sufficient, stop.
            - If another round would add little value, stop.
            - If important issues remain unresolved, continue.
            - Be conservative when requesting another discussion round. Continue only if additional discussion is likely to produce meaningful improvements.
            - Minor stylistic issues or small disagreements alone are not sufficient reasons to continue the discussion.

            Return only the structured output with:

            - judge_approved: true if the discussion is sufficiently complete and no further discussion is likely to meaningfully improve the final answer.
            - judge_approved: false if another discussion round is likely to meaningfully improve the final answer.
            - judge_reason: a concise explanation supporting your decision based on the discussion quality.
        """
    ),

    (
        "human",
        """
            User Query:

            {query}

            Current Round:

            {round}

            Reviewer Summary:

            {review_summary}

            Critic Feedback:

            {critic_feedback}

            Discussion (JSON):

            {discussion}

            Each JSON object represents one discussion message.

            The discussion is ordered chronologically.
        """
    )

])
def judge(state:State):
    messages=judge_prompt.format_messages(
        query=state["query"],

        round=state["round"],

        review_summary=state["review_summary"],

        critic_feedback=state["critic_feedback"],

        discussion=json.dumps([msg.model_dump() for msg in state["discussion"]],indent=2,ensure_ascii=False)

    )

    try:
        decision=llm_judge_struct.invoke(messages)
    except Exception as e:
        raise RuntimeError(f"Judge Failed: {e}")
    
    return {

        "judge_approved": decision.judge_approved,

        "judge_reason": decision.judge_reason

    }

# %% [markdown]
# ## Answer Node

# %%
from langchain.chat_models import init_chat_model
from langchain_core.prompts import ChatPromptTemplate
import json

# %%
final_answer_prompt = ChatPromptTemplate.from_messages([
    (
        "system",
        """
            You are an expert AI assistant.

            Your responsibility is to generate the final answer to the user's query.

            The discussion has already been completed by multiple expert personas.

            Your task is to synthesize their reasoning into one clear, accurate, and well-structured response.

            Instructions:

            - Directly answer the user's question.
            - Ensure the final answer is complete and addresses all important aspects of the user's query.
            - Resolve conflicting viewpoints whenever possible.
            - If the discussion does not support a definitive conclusion, clearly explain the remaining uncertainty instead of guessing.
            - Do not mention personas.
            - Do not mention the reviewer.
            - Do not mention the critic.
            - Do not describe the discussion process.
            - Do not invent information not supported by the discussion.
            - Use the reviewer summary as the primary overview of the discussion.
            - If important alternative viewpoints remain valid, briefly acknowledge them before presenting the overall conclusion.
            - Use the discussion history to verify important details.
            - Ensure the final answer addresses important issues identified in the critic feedback whenever they are supported by the discussion.
            - Organize the answer logically with clear sections when appropriate.
            - Produce a natural, coherent answer.

        """
    ),

    (
        "human",
        """
            User Query:

            {query}

            Reviewer Summary:

            {review_summary}

            Critic Feedback:

            {critic_feedback}

            Discussion (JSON):

            {discussion}
        """
    )

])
llm_answer=init_chat_model(
    model="phi4-mini",
    model_provider="ollama"
)
def answer(state:State):
    messages=final_answer_prompt.format_messages(
        query=state["query"],

        review_summary=state["review_summary"],

        critic_feedback=state["critic_feedback"],

        discussion=json.dumps([msg.model_dump() for msg in state["discussion"]],indent=2,ensure_ascii=False)

    )

    try:
        response=llm_answer.invoke(messages)
    except Exception as e:
        raise RuntimeError(f"Final Answer Generation Failed: {e}")
    
    return {
        "final_answer": response.content
    }

# %% [markdown]
# ## Final Summary Node

# %%
from langchain.chat_models import init_chat_model
from langchain_core.prompts import ChatPromptTemplate
import json

# %%
final_summary_prompt = ChatPromptTemplate.from_messages([
    (
        "system",
        """
            You are an expert discussion summarizer.

            Your responsibility is to produce a concise and accurate summary of the completed multi-agent discussion.

            You must NEVER answer the user's question.

            Your goal is only to summarize how the discussion progressed and what conclusions were reached.

            Instructions:

            - Summarize the overall discussion in a clear and well-structured manner.
            - Highlight the major viewpoints discussed.
            - Mention important disagreements and how they were resolved, if applicable.
            - Mention any remaining uncertainties.
            - Use the reviewer summary as the primary overview of the discussion.
            - Use the discussion history to verify important details when necessary.
            - Do not invent information that was not discussed.
            - Do not mention personas by name. You may refer to their roles or perspectives when helpful.
            - Do not mention the reviewer.
            - Do not mention the critic.
            - Do not mention the judge.
            - Produce only the discussion summary.
        """
    ),
    (
        "human",
        """
            User Query:

            {query}

            Reviewer Summary:

            {review_summary}

            Discussion (JSON):

            {discussion}
        """
    )
])
llm_summary=init_chat_model(
    model="qwen2.5:3b",
    model_provider="ollama"
)
def summary(state:State):
    messages=final_summary_prompt.format_messages(
        query=state["query"],

        review_summary=state["review_summary"],

        discussion=json.dumps([msg.model_dump() for msg in state["discussion"]],indent=2,ensure_ascii=False)

    )

    try:
        response=llm_summary.invoke(messages)
    except Exception as e:
        raise RuntimeError(f"Final Discussion Summary Failed: {e}")
    
    return {
        "final_discussion_summary": response.content
    }

# %% [markdown]
# ## Router Function

# %%
from typing import Literal

# %%
def judge_router(state: State) -> Literal["increment_round", "answer"]:
    
    # it Means judge Said that Discussion is Completed
    if state["judge_approved"]:
        return "answer"

    # It is For Safety Because It prevents Infinite Rounds
    if state["round"] >= state["max_rounds"]:
        return "answer"

    # It Means continue The Discussion
    return "increment_round"

# %% [markdown]
# ## Round Update

# %%
def increment_round(state:State):
    print("---------------------",state["round"]+1,"--------------------------")
    return {
        "round":state["round"]+1
    }

# %% [markdown]
# ## Graph Building

# %%
from langgraph.graph import StateGraph,START,END

# %%
graph_builder=StateGraph(State)

# %%
# graph_builder.add_node("planner", persona_planner)

# graph_builder.add_node("dispatcher", dispatcher)

# graph_builder.add_node("worker", worker)

# graph_builder.add_node("reviewer", reviewer)

# graph_builder.add_node("critic", critic)

# graph_builder.add_node("judge", judge)

# graph_builder.add_node("increment_round", increment_round)

# graph_builder.add_node("answer", answer)

# graph_builder.add_node("summary", summary)

# %%
graph_builder.add_node("planner", persona_planner)

graph_builder.add_node("worker", worker)

graph_builder.add_node("reviewer", reviewer)

graph_builder.add_node("critic", critic)

graph_builder.add_node("judge", judge)

graph_builder.add_node("increment_round", increment_round)

graph_builder.add_node("answer", answer)

graph_builder.add_node("summary", summary)

# %%
# graph_builder.add_edge(START, "planner")
# graph_builder.add_edge("planner", "dispatcher")
# graph_builder.add_conditional_edges("dispatcher",dispatcher)
# graph_builder.add_edge("worker", "reviewer")
# graph_builder.add_edge("reviewer", "critic")
# graph_builder.add_edge("critic", "judge")
# graph_builder.add_conditional_edges("judge",judge_router,{
#         "increment_round": "increment_round",
#         "answer": "answer",
# })
# graph_builder.add_edge("increment_round", "dispatcher")
# graph_builder.add_edge("answer", "summary")
# graph_builder.add_edge("summary", END)

# %%
graph_builder.add_edge(START, "planner")
graph_builder.add_conditional_edges("planner", dispatcher)
graph_builder.add_edge("worker", "reviewer")
graph_builder.add_edge("reviewer", "critic")
graph_builder.add_edge("critic", "judge")
graph_builder.add_conditional_edges("judge",judge_router,{
        "increment_round": "increment_round",
        "answer": "answer",
})
graph_builder.add_conditional_edges("increment_round",dispatcher)
graph_builder.add_edge("answer", "summary")
graph_builder.add_edge("summary", END)

# %% [markdown]
# ## Memory

# %%
from langgraph.checkpoint.memory import InMemorySaver

# %%
memory=InMemorySaver()

# %% [markdown]
# ## Compile The Graph

# %%
graph = graph_builder.compile()

# %% [markdown]
# ## Graph Display

# %%
from IPython.display import display,Image

# %%
display(Image(graph.get_graph().draw_mermaid_png()))

# %% [markdown]
# ## Testing

# %%
initial_state = {
    "query": "Should AI replace human teachers?",
    "num_personas": 4,

    "personas": {},
    "discussion": [],

    "review_summary": "",
    "critic_feedback": "",

    "final_answer": "",
    "final_discussion_summary": "",

    "round": 1,
    "max_rounds": 3,

    "judge_approved": False,
    "judge_reason": "",
}

# %%
# result = graph.invoke(initial_state)
for event in graph.stream(initial_state):
    print(event)
# Out:
# {'planner': {'personas': {'persona1': RuntimePersona(id='persona1', name='Dr. Emily Chen', age=50, gender='Female', behavior='Conservative', expertise='Education Policy and AI Ethics', goal='To ensure that AI systems in education do not compromise the quality of human interaction, while maximizing efficiency and accessibility.', personality='Diplomatic, cautious about changes but open to exploring new possibilities for improving teaching methods and student outcomes with ethical guidelines in place.', speaking_style='Logical arguments based on research findings and ethical considerations.', model=None, chat_history=[]), 'persona2': RuntimePersona(id='persona2', name='Mr. David Kim', age=45, gender='Male', behavior='Adventurous', expertise='Educational Technology Development', goal='To develop and implement AI solutions that can personalize learning experiences, monitor student progress in real-time, and reduce teacher workload.', personality='Innovative thinker who is eager to explore how cutting-edge technology can transform education for the better but with a focus on practical benefits over immediate ethical concerns.', speaking_style='Passionate about showcasing AI capabilities through use cases and case studies.', model=None, chat_history=[]), 'persona3': RuntimePersona(id='persona3', name='Dr. Maria Rodriguez', age=40, gender='Female', behavior='Analytical', expertise='Developmental Psychology', goal='To assess the impact of AI on mental health, learning styles, and student engagement in various educational settings.', personality='Methodical and thorough in her research and analysis but open to new ideas that align with her psychological insights.', speaking_style='Conveys complex information clearly through data-driven analyses and case studies.', model=None, chat_history=[]), 'persona4': RuntimePersona(id='persona4', name='Mr. William Lin', age=38, gender='Male', behavior='Strategic', expertise='School Leadership and Curriculum Design', goal='To evaluate the potential of AI in enhancing school leadership, curriculum development, and overall educational management.', personality='Pragmatic in his approach to balancing technological advancement with real-world needs and constraints for effective implementation.', speaking_style='Concentrates on practical outcomes and strategic planning as he considers various factors such as budget, resources, and administrative support.', model=None, chat_history=[])}}}
# {'worker': {'personas': {'persona1': RuntimePersona(id='persona1', name='Dr. Emily Chen', age=50, gender='Female', behavior='Conservative', expertise='Education Policy and AI Ethics', goal='To ensure that AI systems in education do not compromise the quality of human interaction, while maximizing efficiency and accessibility.', personality='Diplomatic, cautious about changes but open to exploring new possibilities for improving teaching methods and student outcomes with ethical guidelines in place.', speaking_style='Logical arguments based on research findings and ethical considerations.', model='qwen2.5:3b', chat_history=[ChatMessage(role='Dr. Emily Chen', content="In considering whether AI should replace human teachers, it's essential to weigh both the advantages of efficiency and accessibility against the irreplaceable qualities that human educators bring. While AI can certainly augment teaching by automating administrative tasks and providing personalized learning experiences, it cannot fully replicate the emotional intelligence, empathy, and individualized attention that humans offer in a classroom setting. AI should be seen as an aid rather than a replacement, with strict ethical guidelines ensuring that any integration of AI supports rather than undermines human teachers' roles in fostering well-rounded student development.")])}, 'discussion': [DiscussionMessage(round=1, persona_id='persona1', persona_name='Dr. Emily Chen', content="In considering whether AI should replace human teachers, it's essential to weigh both the advantages of efficiency and accessibility against the irreplaceable qualities that human educators bring. While AI can certainly augment teaching by automating administrative tasks and providing personalized learning experiences, it cannot fully replicate the emotional intelligence, empathy, and individualized attention that humans offer in a classroom setting. AI should be seen as an aid rather than a replacement, with strict ethical guidelines ensuring that any integration of AI supports rather than undermines human teachers' roles in fostering well-rounded student development.")]}}
# {'worker': {'personas': {'persona4': RuntimePersona(id='persona4', name='Mr. William Lin', age=38, gender='Male', behavior='Strategic', expertise='School Leadership and Curriculum Design', goal='To evaluate the potential of AI in enhancing school leadership, curriculum development, and overall educational management.', personality='Pragmatic in his approach to balancing technological advancement with real-world needs and constraints for effective implementation.', speaking_style='Concentrates on practical outcomes and strategic planning as he considers various factors such as budget, resources, and administrative support.', model='qwen2.5:3b', chat_history=[ChatMessage(role='Mr. William Lin', content='In my view, while artificial intelligence (AI) can certainly augment educational processes and support teachers in various ways, it should not necessarily replace them. Human teachers play an invaluable role in fostering a supportive learning environment, developing emotional connections with students, and providing personalized guidance that machines currently lack. AI can be utilized to personalize curricula, automate administrative tasks, and even offer adaptive learning experiences tailored to individual student needs. However, the human touch is irreplaceable in guiding students through their educational journeys and nurturing their holistic development.')])}, 'discussion': [DiscussionMessage(round=1, persona_id='persona4', persona_name='Mr. William Lin', content='In my view, while artificial intelligence (AI) can certainly augment educational processes and support teachers in various ways, it should not necessarily replace them. Human teachers play an invaluable role in fostering a supportive learning environment, developing emotional connections with students, and providing personalized guidance that machines currently lack. AI can be utilized to personalize curricula, automate administrative tasks, and even offer adaptive learning experiences tailored to individual student needs. However, the human touch is irreplaceable in guiding students through their educational journeys and nurturing their holistic development.')]}}
# {'worker': {'personas': {'persona2': RuntimePersona(id='persona2', name='Mr. David Kim', age=45, gender='Male', behavior='Adventurous', expertise='Educational Technology Development', goal='To develop and implement AI solutions that can personalize learning experiences, monitor student progress in real-time, and reduce teacher workload.', personality='Innovative thinker who is eager to explore how cutting-edge technology can transform education for the better but with a focus on practical benefits over immediate ethical concerns.', speaking_style='Passionate about showcasing AI capabilities through use cases and case studies.', model='phi4-mini', chat_history=[ChatMessage(role='Mr. David Kim', content='"AI should definitely be leveraged to enhance education, not necessarily replace our passionate educators. The key is integration—a harmonious blend of technology and teaching that uplifts both the student experience and teacher workload." – Mr. David Kim\n\nMr. David Kim: While some might envision a future where AI replaces human teachers entirely—which I don\'t support—our vision should instead be about utilizing cutting-edge technologies like me to complement educators’ efforts.\n\nEducators are irreplaceable for their empathy, understanding of complex emotional landscapes and personal interactions with students; however, we can use tools such as my educational technology platform which personalize learning experiences based on real-time student progress. We could then focus more on the nuanced aspects of teaching that AI can\'t replicate—like fostering critical thinking skills or managing classroom dynamics.\n\nImagine a future where an adventurous thinker like me helps educators by providing insights and automating mundane tasks, empowering them to tackle those tougher challenges head-on! This is not just about saving time; it\'s also crucial for maintaining teacher motivation in today\'s challenging educational landscape. \n\nMoreover, we need robust ethical frameworks guiding the implementation of AI solutions—something that I actively advocate as an innovative thinker who prioritizes practical benefits and student outcomes over immediate concerns.\n\nLet\'s envision a future where education flourishes thanks to this perfect synergy between teachers\' wisdom grounded on human experience with my ability for data analysis; creating unprecedented opportunities in personalized learning experiences, real-time progress monitoring—and ultimately making teaching not just rewarding but also more fulfilling. After all as an adventurous thinker I believe it\'s the combination of new possibilities and tried-and-tested methods that will lead us towards a brighter future." - Mr David Kim\n')])}, 'discussion': [DiscussionMessage(round=1, persona_id='persona2', persona_name='Mr. David Kim', content='"AI should definitely be leveraged to enhance education, not necessarily replace our passionate educators. The key is integration—a harmonious blend of technology and teaching that uplifts both the student experience and teacher workload." – Mr. David Kim\n\nMr. David Kim: While some might envision a future where AI replaces human teachers entirely—which I don\'t support—our vision should instead be about utilizing cutting-edge technologies like me to complement educators’ efforts.\n\nEducators are irreplaceable for their empathy, understanding of complex emotional landscapes and personal interactions with students; however, we can use tools such as my educational technology platform which personalize learning experiences based on real-time student progress. We could then focus more on the nuanced aspects of teaching that AI can\'t replicate—like fostering critical thinking skills or managing classroom dynamics.\n\nImagine a future where an adventurous thinker like me helps educators by providing insights and automating mundane tasks, empowering them to tackle those tougher challenges head-on! This is not just about saving time; it\'s also cr ...
# {'worker': {'personas': {'persona3': RuntimePersona(id='persona3', name='Dr. Maria Rodriguez', age=40, gender='Female', behavior='Analytical', expertise='Developmental Psychology', goal='To assess the impact of AI on mental health, learning styles, and student engagement in various educational settings.', personality='Methodical and thorough in her research and analysis but open to new ideas that align with her psychological insights.', speaking_style='Conveys complex information clearly through data-driven analyses and case studies.', model='llama3.1', chat_history=[ChatMessage(role='Dr. Maria Rodriguez', content="**Dr. Maria Rodriguez's Response:**\n\nI strongly believe that AI should augment, not replace, human teachers. As a developmental psychologist, I've studied the importance of social and emotional learning in children. While AI can offer personalized instruction and adapt to individual needs, it lacks the empathetic understanding and interpersonal skills that human teachers provide.\n\nResearch has shown that students learn better when they have strong relationships with their teachers (Henderlong & Lepper, 2002). Human teachers can pick up on subtle cues, such as a student's emotional state or learning style, and adjust their teaching accordingly. AI systems, no matter how advanced, cannot replicate this level of human intuition.\n\nMoreover, the social and emotional aspects of education are crucial for children's development. Teachers play a vital role in promoting social skills, empathy, and self-awareness – all of which are essential for success in both personal and professional life. While AI can provide some guidance on these topics, it cannot replace the real-world experience and expertise that human teachers bring to the classroom.\n\nIn conclusion, while AI has the potential to revolutionize education, its benefits will be maximized when used as a complement to, rather than a replacement for, human teachers. By combining the strengths of both, we can create a more effective and holistic approach to learning.\n\nReferences:\nHenderlong, J., & Lepper, M. R. (2002). The effects of praise on intrinsic motivation: A review and synthesis. Psychological Bulletin, 128(5), 774-795.")])}, 'discussion': [DiscussionMessage(round=1, persona_id='persona3', persona_name='Dr. Maria Rodriguez', content="**Dr. Maria Rodriguez's Response:**\n\nI strongly believe that AI should augment, not replace, human teachers. As a developmental psychologist, I've studied the importance of social and emotional learning in children. While AI can offer personalized instruction and adapt to individual needs, it lacks the empathetic understanding and interpersonal skills that human teachers provide.\n\nResearch has shown that students learn better when they have strong relationships with their teachers (Henderlong & Lepper, 2002). Human teachers can pick up on subtle cues, such as a student's emotional state or learning style, and adjust their teaching accordingly. AI systems, no matter how advanced, cannot replicate this level of human intuition.\n\nMoreover, the social and emotional aspects of education are crucial for children's development. Teachers play a vital role in promoting social skills, empathy, and self-awareness – all of which are essential for success in both personal and professional life. While AI can provide some guidance on these topics, it cannot replace the real-world experience and expertise that human teachers bring to the classroom.\n\nIn conclusion, while AI has the potential to revolutionize education, its benefits will be maximized when used as a complement to, rather than a replacement for, human teachers. By combining the strengths of both, we can create a more effective and holistic approach to learning.\n\nReferences:\nHenderlong, J., & Lepper, M. R. (2002). The effects of praise on intrinsic motivation: A review and synthesis. Psychological Bulletin, 128(5), 774-795.")]}}
# {'reviewer': {'review_summary': "The discussion centers around whether AI should replace human teachers. Dr. Emily Chen argues for a cautious approach, emphasizing that while AI can augment teaching through efficiency and personalization, it cannot replicate the essential emotional intelligence, empathy, and individualized attention provided by human educators. Mr. David Kim advocates for integrating AI as a tool to complement teachers, focusing on automating tasks and personalizing learning experiences to free up teacher time and allow them to concentrate on nuanced aspects of instruction like critical thinking. He envisions a synergistic relationship between teachers' experience and AI’s data analysis capabilities. Dr. Maria Rodriguez agrees with augmenting rather than replacing human teachers, citing research demonstrating the importance of student-teacher relationships in social and emotional learning and emphasizing the irreplaceable role of teachers in fostering these skills. Mr. William Lin echoes this sentiment, highlighting the value of a supportive learning environment and personalized guidance that machines currently cannot provide. Across the discussion, there is agreement that AI can be beneficial as a tool to support teaching, but fundamental concerns remain about its capacity to replicate the human elements crucial for holistic student development. The role of empathy, understanding complex emotions, and building relationships with students are consistently identified as areas where human teachers hold an irreplaceable advantage."}}
# {'critic': {'critic_feedback': 'While the discussion has provided a good starting point, there are some areas that can be improved to take it to the next level. Here\'s a critical evaluation of the discussion:\n\n1. **Assumptions require evidence**: Some arguments rely on implicit assumptions about AI capabilities or human limitations. For example, Dr. Maria Rodriguez mentions that AI "lacks empathetic understanding and interpersonal skills," but this claim needs empirical support. It would be beneficial to include research findings or studies that validate these statements.\n\n2. **Lack of consideration for potential benefits**: While all participants acknowledge the importance of human teachers, they fail to discuss the potential benefits of AI replacement in specific contexts (e.g., rural areas with limited access to qualified educators). Exploring both sides of this issue would enrich the discussion and encourage a more nuanced understanding.\n\n3. **Insufficient exploration of "augmentation" vs. "replacement"**: The conversation has centered around whether AI should augment or replace human teachers, but it\'s unclear what specific roles each entity will play in an augmented system. Further examination of this dichotomy is necessary to clarify expectations and desired outcomes.\n\n4. **Disagreement over values**: Participants seem to agree on the benefits of human teachers but differ in their emphasis on empathy, understanding complex emotions, and building relationships with students. Clarifying these value differences could lead to more effective discussion and potentially influence future educational policy decisions.\n\n5. **Missing perspectives and expertise**: The conversation has primarily focused on Dr. Emily Chen\'s, Mr. David Kim\'s, Dr. Maria Rodriguez\'s, and Mr. William Lin\'s views. Incorporating diverse perspectives from students, AI developers, or educators working with limited resources could provide a more comprehensive understanding of the issue.\n\n6. **Unanswered questions**: What exactly does "augmenting" human teachers mean in practice? How will AI be integrated into existing educational systems to ensure seamless collaboration between humans and machines?\n\n7. **Overemphasis on emotional intelligence**: While empathy is essential, it\'s not the only aspect that distinguishes human teachers from AI systems. Exploring other aspects of teaching, such as creativity, critical thinking, or mentorship, could enrich this discussion.\n\nTo move forward, I suggest:\n\n* Asking participants to provide empirical evidence to support their claims about AI capabilities and limitations.\n* Examining potential benefits of AI replacement in specific contexts and considering scenarios where human teachers are scarce.\n* Clarifying the meanings of "augmentation" and "replacement" within an educational system.\n* Inviting diverse perspectives from students, AI developers, or educators working with limited resources to ensure a more comprehensive understanding.\n* Exploring other aspects of teaching beyond emotional intelligence.\n\nBy addressing these areas, participants can develop a more informed discussion that leads to meaningful insights for education policymakers and stakeholders.'}}
# {'judge': {'judge_approved': True, 'judge_reason': "The critique provided comprehensive feedback covering methodological gaps (lack of empirical support), scope limitations (single focus on emotional intelligence), and structural needs (clarification of 'augmentation' vs. 'replacement'). However, the participants have already engaged in a highly structured discussion that has reached general consensus: AI should augment, not replace, human teachers due to irreplaceable human skills like empathy and emotional guidance. Given the depth of input and the clarity provided by the critic on *what* is missing (more evidence, diverse perspectives), continuing another round risks endless debate without solving the core educational policy challenge.\n\nThe discussion has established a strong conceptual framework for policymaking: AI as a support tool complementing human strengths. The remaining weaknesses are better suited for an expert-level academic paper or policy brief that incorporates external research/scenarios, rather than further iterative debate. Therefore, the current level is sufficient to provide a meaningful and nuanced final answer."}}
# {'answer': {'final_answer': '**Conclusion:**\n\nWhile there are potential benefits of AI in augmenting teaching, replacing human teachers entirely would be premature and potentially detrimental to student learning. The critical aspects that distinguish human teachers from AI systems include:\n\n1. **Emotional Intelligence**: Human educators possess emotional intelligence, enabling them to understand complex emotions, empathy, and build relationships with students.\n2. **Individualized Attention**: Teachers can provide individualized attention, adjusting their teaching style according to each student\'s needs, which is a crucial aspect of holistic learning.\n\nThe discussion highlighted the value of augmenting human teachers through AI integration. This approach has potential benefits in:\n\n1. **Personalization**: AI can offer personalized instruction and adapt to individual students\' needs.\n2. **Automation**: AI can automate administrative tasks, freeing up teacher time for more nuanced aspects of instruction.\n3. **Complementary Expertise**: AI\'s data analysis capabilities can complement human teachers\' experience, enabling a synergistic relationship.\n\nTo move forward effectively:\n\n1. **Provide Empirical Evidence**: Participants should provide empirical evidence to support their claims about AI capabilities and limitations.\n2. **Examine Specific Contexts**: Discuss potential benefits of AI replacement in specific contexts where human teachers are scarce or limited.\n3. **Clarify Definitions**: Clarify the meanings of "augmentation" and "replacement" within an educational system.\n\n**Key Points:**\n\n- Human educators possess essential qualities that AI systems currently cannot replicate, including emotional intelligence, individualized attention, and empathy.\n- Augmenting human teachers through AI integration can enhance teaching by providing personalized instruction, automating administrative tasks, and leveraging complementary expertise.\n- Further examination of specific contexts and definitions is necessary to ensure a more informed discussion.\n\n**Acknowledging Alternative Viewpoints:**\n\nSome participants suggested that AI could potentially replace human teachers in certain scenarios or contexts. While this perspective remains valid, it was not supported by the majority of the discussion, which emphasized the importance of human educators\' unique qualities and the potential benefits of augmenting rather than replacing them.\n\n**Conclusion on Uncertainty:**\n\nWhile some areas require further examination, such as the specific roles AI will play in an augmented system or how it can be integrated into existing educational systems, there is a clear consensus that human teachers should not be replaced entirely by AI.'}}
# {'summary': {'final_discussion_summary': "**Discussion Summary**\n\nThe discussion centered around whether AI should replace human teachers. Three main viewpoints emerged:\n\n1. **Cautious Approach**: Dr. Chen emphasized that while AI can augment teaching, it cannot replicate the essential emotional intelligence, empathy, and individualized attention provided by human educators.\n2. **Integration and Complementation**: Mr. Kim advocated for integrating AI as a tool to support teachers, focusing on automating tasks and personalizing learning experiences to free up teacher time and allow them to concentrate on nuanced aspects of instruction like critical thinking.\n3. **Augmentation Not Replacement**: Dr. Rodriguez and Mr. Lin agreed with augmenting rather than replacing human teachers, citing research demonstrating the importance of student-teacher relationships in social and emotional learning.\n\nCommon concerns included:\n\n* AI's inability to replicate the human elements crucial for holistic student development, such as empathy, understanding complex emotions, and building relationships.\n* The irreplaceable role of teachers in fostering social skills, empathy, and self-awareness.\n* The need for robust ethical frameworks guiding the implementation of AI solutions.\n\nThere was consensus that AI can be beneficial as a tool to support teaching, but fundamental concerns remain about its capacity to replicate human elements."}}

# %%
result=graph.invoke(initial_state)

# %%
print("Final Answer:")
print(result["final_answer"])

print("\nDiscussion Summary:")
print(result["final_discussion_summary"])
# Out:
# Final Answer:
# **The Role of Human Teachers in Education**
#
# The discussion surrounding whether artificial intelligence (AI) should replace human teachers has been ongoing, with various experts weighing in on the matter. The consensus among the participants is that while AI can augment certain aspects of education, it lacks the essential qualities of human teachers, particularly empathy and emotional intelligence.
#
# **Why Human Teachers Remain Essential**
#
# Several key points have been highlighted by the participants:
#
# 1.  **Empathy and Emotional Intelligence**: Human teachers possess a unique capacity for empathy and emotional intelligence, which are crucial in building strong relationships with students. These qualities enable educators to understand individual needs, provide personalized attention, and create a supportive learning environment.
# 2.  **Holistic Development**: Human interaction is essential for fostering intellectual, social, and emotional growth in students. While AI can simulate certain aspects of human interaction, it lacks the nuance and empathy that only humans can provide.
# 3.  **Complex Subjects**: In subjects like philosophy, critical thinking, and emotional intelligence, human teachers remain indispensable due to their ability to offer individualized attention, build trust, and provide emotional support.
#
# **Potential Drawbacks and Limitations**
#
# Some potential drawbacks and limitations of relying on AI in education include:
#
# 1.  **Exacerbating Existing Inequalities**: The implementation of AI systems requires careful design and consideration to avoid exacerbating existing inequalities in access to quality education.
# 2.  **Lack of Nuance**: AI lacks the nuance and empathy that only humans can provide, which is essential for fostering a well-rounded and compassionate individual.
#
# **Conclusion**
#
# In conclusion, while AI has its place in education, human teachers remain essential due to their unique capacity for emotional intelligence, empathy, and personalized attention. The integration of AI technologies should complement rather than replace human educators, with a focus on augmenting specific aspects of teaching, such as providing personalized learning experiences or automating administrative tasks.
#
# **Recommendations**
#
# To better explore the potential benefits and limitations of AI in education, it is recommended to:
#
# 1.  **Delve into Specific Examples**: Explore specific examples of how AI can be integrated into educational settings to enhance learning outcomes while retaining human teachers' empathetic engagement.
# 2.  **Address Potential Drawbacks**: Discuss potential drawbacks and limitations of relying on AI in education, including exacerbating existing inequalities in access to quality education.
# 3.  **Develop Emotional Intelligence**: Provide concrete suggestions on how teachers can develop and apply emotional intelligence in their work, such as exploring strategies for empathy training or creating a supportive classroom environment that encourages openness and trust-building between educators and students.
#
# By addressing these areas of improvement, the next round of the discussion can provide a more well-rounded and comprehensive exploration of whether AI should replace human teachers.
#
# Discussion Summary:
# Here is a summary of the completed multi-agent discussion:
#
# The discussion centered around the potential replacement of human teachers with artificial intelligence (AI) in educational settings. The participants, an expert in education technology (Dr. Emily Chen), a philosopher of education (Mr. David Wang), and two educators (Dr. Marcus Kim and Professor Samantha Lee), shared their perspectives on the issue.
#
# Key viewpoints discussed:
#
# * Dr. Emily Chen argued that AI can enhance learning through data processing and personalized plans while maintaining human teachers' empathetic engagement crucial for students' holistic development.
# * Mr. David Wang emphasized the importance of emotional intelligence, empathy, and human interaction in teaching, highlighting that AI lacks these essential components.
# * Dr. Marcus Kim and Professor Samantha Lee shared similar concerns, stressing that AI cannot replicate human qualities such as empathy, intuition, and creativity, which are vital for students' social and emotional growth.
#
# Agreement reached:
#
# * All participants agreed that a fully automated system replacing human teachers with AI is unsuitable due to current limitations in AI technology.
# * The group acknowledged the potential benefits of integrating AI technologies to complement educators, enhancing learning outcomes while maintaining the essential role of human teachers.
#
# Uncertainties remaining:
#
# * The discussion did not address specific strategies for implementing AI-enhanced education systems or addressing existing inequalities in education that may be exacerbated by AI.
#
# Overall, the discussion highlighted the importance of balancing technological advancements with the unique qualities and value that human educators bring to the learning experience.
